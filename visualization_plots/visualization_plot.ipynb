# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %% [markdown]
# ## Diffuse

# %% [markdown]
# ### banknote

# %%
rule = "diffuse"

# %%
name = "banknote"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
bn_diffuse_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]
print(bn_diffuse_rmse)
# Out:
#          GAIN  Baseline RMSE  TabCSDI  Unnamed: 0        MF      MICE  \
# 0.25  0.05963        0.47535      NaN           0  0.440514  0.549045
# 0.50  1.04515        0.56557      NaN           2  0.559332  0.590456
# 0.75  0.70441        0.75973      NaN           1  0.568586  0.626311
#
#           Mean
# 0.25  0.804147
# 0.50  0.750727
# 0.75  0.732530

# %% [markdown]
# ### cc

# %%
# concrete_compression
name = "concrete_compression"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
cc_diffuse_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]

print(cc_diffuse_rmse)
# Out:
#          GAIN  Baseline RMSE  TabCSDI  Unnamed: 0        MF      MICE  \
# 0.25  0.17673        0.52180      NaN           0  0.430142  0.194108
# 0.50  0.47531        0.49682      NaN           2  0.396888  0.367338
# 0.75  0.92288        0.85084      NaN           1  0.465812  0.412333
#
#           Mean
# 0.25  0.449719
# 0.50  0.403490
# 0.75  0.432126

# %%
name = "wine_quality_red"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
rd_diffuse_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]

print(rd_diffuse_rmse)
# Out:
#          GAIN  Baseline RMSE  TabCSDI  Unnamed: 0        MF      MICE  \
# 0.25  0.11209        0.20050      NaN           0  0.067062  0.069028
# 0.50  0.06711        0.26313      NaN           2  0.098816  0.093470
# 0.75  0.25737        0.35855      NaN           1  0.126950  0.135520
#
#           Mean
# 0.25  0.095600
# 0.50  0.106967
# 0.75  0.126385

# %%
name = "wine_quality_white"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

# tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
# tabcsdi.set_index('Missing_Rule', inplace=True)
# tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
wh_diffuse_rmse=  pd.concat([gain,
                                #tabcsdi, 
                                baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]

print(wh_diffuse_rmse)
# Out:
#          GAIN  Baseline RMSE  Unnamed: 0        MF      MICE      Mean
# 0.25  0.01707        0.13518           0  0.052239  0.050884  0.072559
# 0.50  0.02452        0.16743           2  0.067436  0.060029  0.082046
# 0.75  0.06246        0.24870           1  0.087676  0.080935  0.100470

# %% [markdown]
# ## Logistic

# %%
rule = "logistic"

# %%
name = "banknote"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = bank_diffuse_tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
bn_logistic_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]
print(bn_logistic_rmse)
# Out:
#          GAIN  Baseline RMSE  TabCSDI  Unnamed: 0        MF      MICE  \
# 0.25  0.19796        0.21082      NaN           0  0.455485  0.400026
# 0.50  0.06489        0.20666      NaN           2  0.418764  0.397064
# 0.75  0.04518        0.20090      NaN           1  0.265156  0.318169
#
#           Mean
# 0.25  0.433656
# 0.50  0.415260
# 0.75  0.422291

# %%
name = "concrete_compression"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = bank_diffuse_tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)
#####################

cc_logistic_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]
print(cc_logistic_rmse)
# Out:
#          GAIN  Baseline RMSE  TabCSDI  Unnamed: 0        MF      MICE  \
# 0.25  0.09325        0.24590      NaN           0  0.209745  0.210329
# 0.50  0.08575        0.23783      NaN           2  0.146490  0.182199
# 0.75  0.05552        0.21888      NaN           1  0.115399  0.154900
#
#           Mean
# 0.25  0.194359
# 0.50  0.188022
# 0.75  0.184564

# %%
name = "wine_quality_white"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

# tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
# tabcsdi.set_index('Missing_Rule', inplace=True)
# tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
wh_logistic_rmse=  pd.concat([gain,
                                #tabcsdi, 
                                baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]

print(wh_logistic_rmse)
# Out:
#          GAIN  Baseline RMSE  Unnamed: 0        MF      MICE      Mean
# 0.25  0.04889        0.14622           0  0.077260  0.072864  0.075516
# 0.50  0.04763        0.11760           2  0.064314  0.070775  0.074820
# 0.75  0.01978        0.13630           1  0.050657  0.055135  0.072430

# %%
name = "wine_quality_red"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../baselines/{name}_baseline_{rule}.csv").sort_values(by='Rule', ascending=True)
baseline.set_index('Rule', inplace=True)

#####################
rd_logistic_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
y_columns = ["GAIN","MF","MICE","Mean"]

print(rd_logistic_rmse)
# Out:
#          GAIN  Baseline RMSE   TabCSDI  Unnamed: 0        MF      MICE  \
# 0.25  0.06484        0.16447  0.157815           0  0.093315  0.077446
# 0.50  0.04632        0.13919  0.130093           2  0.084258  0.083243
# 0.75  0.03012        0.14608  0.133599           1  0.060519  0.070872
#
#           Mean
# 0.25  0.078572
# 0.50  0.085747
# 0.75  0.081983

# %%
# 提取 x 轴的数据（在这里使用了 'Unnamed: 0' 列）
x = cc_logistic_rmse.index


fig, axes = plt.subplots(4, 2, figsize=(12, 16))

#######################################################
# Subplot of interest (0, 0 in this example)
name = "Banknote"
ax = axes[0, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, bn_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1.2)
ax.legend()
ax.grid(True)



ax = axes[0, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, bn_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1.2)
ax.legend()
ax.grid(True)

##################################



name = "wine_quality_red"
ax = axes[1, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, rd_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.3)
ax.legend()
ax.grid(True)



ax = axes[1, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, rd_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.3)
ax.legend()
ax.grid(True)

#############################################
# Subplot of interest (0, 0 in this example)
name = "wine_quality_white"
ax = axes[2, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, wh_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.15)
ax.legend()
ax.grid(True)



ax = axes[2, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, wh_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.15)
ax.legend()
ax.grid(True)

##################################
# Subplot of interest (0, 0 in this example)
name = "concrete_compression"
ax = axes[3, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, cc_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1 )
ax.legend()
ax.grid(True)



ax = axes[3, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, cc_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1)
ax.legend()
ax.grid(True)
# Adjust layout
plt.tight_layout()


plt.show()

# %%
bank_logistic_rmse

# %%
# 提取 x 轴的数据（在这里使用了 'Unnamed: 0' 列）
x = bank_logistic_rmse.index


# 创建一个新的图形
plt.figure(figsize=(8, 6))


# 显示图形
plt.grid(True)




plt.show()
