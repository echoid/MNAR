# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %% [markdown]
# ## Diffuse

# %% [markdown]
# ### banknote

# %%
rule = "diffuse"
y_columns = ["GAIN","Mice","Mean","Missforest","KNN"]

# %%
name = "banknote"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

# #####################
bn_diffuse_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)

print(bn_diffuse_rmse)
# Out:
#                  GAIN  Baseline RMSE  TabCSDI      Mean      Mice  Missforest  \
# Missing_Rule
# 0.25          0.05963        0.47535      NaN  0.337351  0.231101    0.127306
# 0.50          1.04515        0.56557      NaN  0.317164  0.259490    0.170128
# 0.75          0.70441        0.75973      NaN  0.322487  0.274370    0.173272
#
#                    KNN
# Missing_Rule
# 0.25          0.136987
# 0.50          0.165189
# 0.75          0.162635

# %%
bn_diffuse_rmse
# Out:
#                  GAIN  Baseline RMSE  TabCSDI      Mean      Mice  Missforest  \
# Missing_Rule
# 0.25          0.05963        0.47535      NaN  0.337351  0.231101    0.127306
# 0.50          1.04515        0.56557      NaN  0.317164  0.259490    0.170128
# 0.75          0.70441        0.75973      NaN  0.322487  0.274370    0.173272
#
#                    KNN
# Missing_Rule
# 0.25          0.136987
# 0.50          0.165189
# 0.75          0.162635

# %% [markdown]
# ### cc

# %%
# concrete_compression
name = "concrete_compression"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

#####################
cc_diffuse_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)

print(cc_diffuse_rmse)
# Out:
#                  GAIN  Baseline RMSE  TabCSDI      Mean      Mice  Missforest  \
# Missing_Rule
# 0.25          0.17673        0.52180      NaN  0.431503  0.401873    0.403299
# 0.50          0.47531        0.49682      NaN  0.369368  0.411984    0.368778
# 0.75          0.92288        0.85084      NaN  0.273436  0.352941    0.344644
#
#                    KNN
# Missing_Rule
# 0.25          0.464868
# 0.50          0.395430
# 0.75          0.253365

# %%
name = "wine_quality_red"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

#####################
rd_diffuse_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)

print(rd_diffuse_rmse)
# Out:
#                  GAIN  Baseline RMSE  TabCSDI      Mean      Mice  Missforest  \
# Missing_Rule
# 0.25          0.11209        0.20050      NaN  0.153543  0.148201    0.104141
# 0.50          0.06711        0.26313      NaN  0.140568  0.157237    0.130500
# 0.75          0.25737        0.35855      NaN  0.130300  0.177527    0.147711
#
#                    KNN
# Missing_Rule
# 0.25          0.119072
# 0.50          0.115415
# 0.75          0.124567

# %%
name = "wine_quality_white"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

# tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
# tabcsdi.set_index('Missing_Rule', inplace=True)
# tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)
#####################
wh_diffuse_rmse=  pd.concat([gain,
                                #tabcsdi, 
                                baseline], axis=1)
print(wh_diffuse_rmse)
# Out:
#                  GAIN  Baseline RMSE      Mean      Mice  Missforest       KNN
# Missing_Rule
# 0.25          0.01707        0.13518  0.104004  0.121194    0.090596  0.110240
# 0.50          0.02452        0.16743  0.101080  0.138670    0.104919  0.120355
# 0.75          0.06246        0.24870  0.108923  0.164880    0.112001  0.142462

# %% [markdown]
# ## Logistic

# %%
rule = "logistic"

# %%
name = "banknote"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

#####################
bn_logistic_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
print(bn_logistic_rmse)
# Out:
#                  GAIN  Baseline RMSE   TabCSDI      Mean      Mice  \
# Missing_Rule
# 0.25          0.19796        0.21082  0.197471  0.200897  0.229676
# 0.50          0.06489        0.20666  0.176595  0.206663  0.257780
# 0.75          0.04518        0.20090  0.160700  0.210821  0.285404
#
#               Missforest       KNN
# Missing_Rule
# 0.25            0.104209  0.178531
# 0.50            0.172003  0.211182
# 0.75            0.202524  0.207536

# %%
name = "concrete_compression"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

#####################

cc_logistic_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)
print(cc_logistic_rmse)
# Out:
#                  GAIN  Baseline RMSE   TabCSDI      Mean      Mice  \
# Missing_Rule
# 0.25          0.09325        0.24590  0.245253  0.218879  0.263395
# 0.50          0.08575        0.23783  0.218959  0.237832  0.305242
# 0.75          0.05552        0.21888  0.185862  0.245903  0.337722
#
#               Missforest       KNN
# Missing_Rule
# 0.25            0.167517  0.212960
# 0.50            0.203501  0.239401
# 0.75            0.257416  0.262322

# %%
name = "wine_quality_white"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

# tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
# tabcsdi.set_index('Missing_Rule', inplace=True)
#tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

#####################
wh_logistic_rmse=  pd.concat([gain,
                                #tabcsdi, 
                                baseline], axis=1)

print(wh_logistic_rmse)
# Out:
#                  GAIN  Baseline RMSE      Mean      Mice  Missforest       KNN
# Missing_Rule
# 0.25          0.04889        0.14622  0.136299  0.123239    0.088160  0.134007
# 0.50          0.04763        0.11760  0.117601  0.139942    0.109655  0.135897
# 0.75          0.01978        0.13630  0.146224  0.185993    0.147816  0.166066

# %%
name = "wine_quality_red"

gain = pd.read_csv(f"../results/gain/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
gain = gain.rename(columns={'Imputer RMSE': "GAIN"})
gain.set_index('Missing_Rule', inplace=True)

tabcsdi = pd.read_csv(f"../results/tabcsdi/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
tabcsdi.set_index('Missing_Rule', inplace=True)
tabcsdi = tabcsdi.rename(columns={'Imputer RMSE': "TabCSDI"})

baseline = pd.read_csv(f"../results/baselines/RMSE_{name}_{rule}.csv").sort_values(by='Missing_Rule', ascending=True)
baseline.set_index('Missing_Rule', inplace=True)

#####################
rd_logistic_rmse=  pd.concat([gain, tabcsdi, baseline], axis=1)

print(rd_logistic_rmse)
# Out:
#                  GAIN  Baseline RMSE   TabCSDI      Mean      Mice  \
# Missing_Rule
# 0.25          0.06484        0.16447  0.157815  0.146085  0.157671
# 0.50          0.04632        0.13919  0.130093  0.139194  0.167867
# 0.75          0.03012        0.14608  0.133599  0.164469  0.224776
#
#               Missforest       KNN
# Missing_Rule
# 0.25            0.111087  0.135753
# 0.50            0.125300  0.156097
# 0.75            0.180806  0.187956

# %%
# 提取 x 轴的数据（在这里使用了 'Unnamed: 0' 列）
x = cc_logistic_rmse.index


fig, axes = plt.subplots(4, 2, figsize=(12, 16))

#######################################################
# Subplot of interest (0, 0 in this example)
name = "Banknote"
ax = axes[0, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, bn_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.5)
ax.legend()
ax.grid(True)



ax = axes[0, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, bn_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1.2)
ax.legend()
ax.grid(True)

##################################



name = "wine_quality_red"
ax = axes[1, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, rd_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.3)
ax.legend()
ax.grid(True)



ax = axes[1, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, rd_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.3)
ax.legend()
ax.grid(True)

#############################################
# Subplot of interest (0, 0 in this example)
name = "wine_quality_white"
ax = axes[2, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, wh_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 0.2)
ax.legend()
ax.grid(True)



ax = axes[2, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, wh_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0,0.2)
ax.legend()
ax.grid(True)

##################################
# Subplot of interest (0, 0 in this example)
name = "concrete_compression"
ax = axes[3, 0]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, cc_logistic_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Logistic - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1 )
ax.legend()
ax.grid(True)



ax = axes[3, 1]

# Plot multiple lines on the selected subplot
for column in y_columns:
    ax.plot(x, cc_diffuse_rmse[column], marker='o', label=column)

# Customize subplot properties
ax.set_xticks(x)
ax.set_title(f'MNAR - Diffuse - {name}')
ax.set_xlabel('Missing Rate')
ax.set_ylabel('RMSE Value')
ax.set_ylim(0, 1)
ax.legend()
ax.grid(True)
# Adjust layout
plt.tight_layout()


plt.show()
